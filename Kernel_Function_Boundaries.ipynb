# %% [markdown]
# # SVM kernel functions generated using some random data from NumPy

# %% [markdown]
# # Linear kernel

# %%
from sklearn import svm
import matplotlib.pyplot as plt
import numpy as np

# generate linearly separable data
X = np.array([[1, 2], [2, 3], [3, 1], [6, 5], [7, 7], [8, 6]])
y = np.array([0, 0, 0, 1, 1, 1])

# fit SVM with linear kernel
clf = svm.SVC(kernel='linear', C=1)
clf.fit(X, y)

# plot data points and SVM decision boundary
plt.scatter(X[:, 0], X[:, 1], c=y)
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# create a grid to evaluate SVM
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf.decision_function(xy).reshape(XX.shape)

# plot SVM decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')

plt.title("Decision boundary with linear SVM kernel")
plt.show()

# %% [markdown]
# # Polynomial kernel

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

# Generate some random data
np.random.seed(0)
X = np.random.randn(200, 2)
y = np.logical_xor(X[:, 0] > 0, X[:, 1] > 0)

# Fit the SVM model with polynomial kernel
clf = svm.SVC(kernel='poly', degree=3, coef0=1)
clf.fit(X, y)

# Create a mesh grid to visualize the decision boundary
xx, yy = np.meshgrid(np.linspace(-3, 3, 500), np.linspace(-3, 3, 500))
Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the data points and decision boundary
plt.contour(xx, yy, Z, levels=[0], linestyles=['-'], colors='k')
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
plt.title("Decision boundary with polynomial SVM kernel")
plt.show()

# %% [markdown]
# # RBF kernel

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

# Generate some random data
np.random.seed(0)
X = np.random.randn(200, 2)
y = np.logical_xor(X[:, 0] > 0, X[:, 1] > 0)

# Fit the SVM model with RBF kernel
clf = svm.SVC(kernel='rbf', gamma=1)
clf.fit(X, y)

# Create a mesh grid to visualize the decision boundary
xx, yy = np.meshgrid(np.linspace(-3, 3, 500), np.linspace(-3, 3, 500))
Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the data points and decision boundary
plt.contour(xx, yy, Z, levels=[0], linestyles=['-'], colors='k')
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
plt.title("Decision boundary with RBF SVM kernel")
plt.show()

# %% [markdown]
# # Sigmoid kernel

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

# Generate some random data
np.random.seed(0)
X = np.random.randn(200, 2)
y = np.logical_xor(X[:, 0] > 0, X[:, 1] > 0)

# Fit the SVM model with sigmoid kernel
clf = svm.SVC(kernel='sigmoid', gamma=0.1, coef0=0)
clf.fit(X, y)

# Create a mesh grid to visualize the decision boundary
xx, yy = np.meshgrid(np.linspace(-3, 3, 500), np.linspace(-3, 3, 500))
Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the data points and decision boundary
plt.contour(xx, yy, Z, levels=[0], linestyles=['-'], colors='k')
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
plt.title("Decision boundary with sigmoid SVM kernel")
plt.show()
